# %%
from torchvision import models, transforms
from torchsummary import summary
import torch
import numpy as np
import cv2
import PIL
import matplotlib.pyplot as plt

import sys
import os

current_dir = os.getcwd()
sys.path.append(os.path.dirname(current_dir))

from lib.src import *
from lib.utils import *

from torchvision.models import resnet50

import random
import os
from tqdm import tqdm

# %%
DICT[153]
# Out:
# (153, 'n02085936', 'maltese_dog')

# %%
MODEL = resnet50(pretrained=True)
TARGET = MODEL.layer4[-1].conv3
IN_IMG = 224

FUNCTION = get_gradcam
HEATMAP = 0.5

CLASS_ID = 153
img = get_image_torch('images/malt_dogs.jpg', IN_IMG, IN_IMG)

cam = FUNCTION(img, MODEL, TARGET, CLASS_ID)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/gradcam_same_class.jpg')
# Out:
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
MODEL = resnet50(pretrained=True)
TARGET = MODEL.layer4[-1].conv3
IN_IMG = 224

FUNCTION = get_hirescam
HEATMAP = 0.5

CLASS_ID = 153
img = get_image_torch('images/malt_dogs.jpg', IN_IMG, IN_IMG)

cam = FUNCTION(img, MODEL, TARGET, CLASS_ID)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/hirescam_same_class.jpg')
# Out:
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
MODEL = resnet50(pretrained=True)
TARGET = MODEL.layer4[-1].conv3
IN_IMG = 224

FUNCTION = get_ablationcam
HEATMAP = 0.5

CLASS_ID = 153
img = get_image_torch('images/malt_dogs.jpg', IN_IMG, IN_IMG)

cam = FUNCTION(img, MODEL, TARGET, CLASS_ID)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/ablationcam_same_class.jpg')
# Out:
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
MODEL = resnet50(pretrained=True)
TARGET = MODEL.layer4[-1].conv3
IN_IMG = 224

FUNCTION = get_xgradcam
HEATMAP = 0.5

CLASS_ID = 153
img = get_image_torch('images/malt_dogs.jpg', IN_IMG, IN_IMG)

cam = FUNCTION(img, MODEL, TARGET, CLASS_ID)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/xgradcam_same_class.jpg')
# Out:
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
MODEL = resnet50(pretrained=True)
TARGET = MODEL.layer4[-1].conv3
IN_IMG = 224

FUNCTION = get_gradcamplusplus
HEATMAP = 0.5

CLASS_ID = 153
img = get_image_torch('images/malt_dogs.jpg', IN_IMG, IN_IMG)

cam = FUNCTION(img, MODEL, TARGET, CLASS_ID)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/gradcamplusplus_same_class.jpg')
# Out:
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
MODEL = resnet50(pretrained=True)
TARGET = MODEL.layer4[-1].conv3
IN_IMG = 224

FUNCTION = get_scorecam
HEATMAP = 0.5

CLASS_ID = 153
img = get_image_torch('images/malt_dogs.jpg', IN_IMG, IN_IMG)

cam = FUNCTION(img, MODEL, TARGET, CLASS_ID)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/scorecam_same_class.jpg')
# Out:
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\kniko\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
