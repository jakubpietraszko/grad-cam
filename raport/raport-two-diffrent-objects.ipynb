# %%
from torchvision import models, transforms
from torchsummary import summary
import torch
import numpy as np
import cv2
import PIL
import matplotlib.pyplot as plt

import sys
import os

current_dir = os.getcwd()
sys.path.append(os.path.dirname(current_dir))

from lib.src import *
from lib.utils import *

from pytorch_grad_cam import GradCAM, HiResCAM, AblationCAM, ScoreCAM, GradCAMPlusPlus, XGradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
from torchvision.models import resnet50

# %%
DICT[229], DICT[284]
# Out:
# ((229, 'n02105641', 'old_english_sheepdog'), (284, 'n02123597', 'siamese_cat'))

# %%
MODEL = resnet50(pretrained=True)
TARGET = MODEL.layer4[-1].conv3
IN_IMG = 224

FUNCTION = get_gradcam
HEATMAP = 0.5

CLASS1 = 229
CLASS2 = 284

img = get_image_torch('images/dog_and_cat.jpg', IN_IMG, IN_IMG)

cam = FUNCTION(img, MODEL, TARGET, CLASS1)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/gradcam_dog_from_dogcat.jpg')

cam = FUNCTION(img, MODEL, TARGET, CLASS2)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/gradcam_cat_from_dogcat.jpg')
# Out:
# /home/jakub/Documents/Tasks/final/grad-cam/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jakub/Documents/Tasks/final/grad-cam/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
MODEL = resnet50(pretrained=True)
TARGET = MODEL.layer4[-1].conv3
IN_IMG = 224

FUNCTION = get_hirescam
HEATMAP = 0.5

CLASS1 = 229
CLASS2 = 284

img = get_image_torch('images/dog_and_cat.jpg', IN_IMG, IN_IMG)

cam = FUNCTION(img, MODEL, TARGET, CLASS1)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/hirescam_dog_from_dogcat.jpg')

cam = FUNCTION(img, MODEL, TARGET, CLASS2)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/hirescam_cat_from_dogcat.jpg')
# Out:
# /home/jakub/Documents/Tasks/final/grad-cam/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jakub/Documents/Tasks/final/grad-cam/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
MODEL = resnet50(pretrained=True)
TARGET = MODEL.layer4[-1].conv3
IN_IMG = 224

FUNCTION = get_ablationcam
HEATMAP = 0.5

CLASS1 = 229
CLASS2 = 284

img = get_image_torch('images/dog_and_cat.jpg', IN_IMG, IN_IMG)

cam = FUNCTION(img, MODEL, TARGET, CLASS1)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/ablationcam_dog_from_dogcat.jpg')

cam = FUNCTION(img, MODEL, TARGET, CLASS2)
overlay_plot_torch(img, cam, HEATMAP, 'raport_images/ablationcam_cat_from_dogcat.jpg')
# Out:
# /home/jakub/Documents/Tasks/final/grad-cam/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jakub/Documents/Tasks/final/grad-cam/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
